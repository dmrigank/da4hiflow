# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
npz_file = np.load("myruns/quicktest/snapshots.npz")
npz_file
# Out:
# NpzFile 'myruns/quicktest/snapshots.npz' with keys: truth, forecast, analysis, observations

# %%
npz_file['truth'].shape
# Out:
# (6, 10)

# %%
plt.imshow(npz_file['truth'].T, aspect='auto')

# %%
plt.imshow(npz_file['analysis'].T, aspect='auto')
