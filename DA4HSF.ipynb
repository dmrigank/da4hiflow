# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
npz_file = np.load("runs/20260303_175739/snapshots.npz")
npz_file
# Out:
# NpzFile 'runs/20260303_175739/snapshots.npz' with keys: truth, forecast_mean, analysis_mean, observations

# %%
npz_file["forecast_mean"].shape
# Out:
# (11, 20)

# %%
plt.imshow(npz_file["truth"].T, aspect="auto")

# %%
plt.imshow(npz_file["forecast_mean"].T, aspect="auto")

# %%
plt.imshow(npz_file["analysis_mean"].T, aspect="auto")
